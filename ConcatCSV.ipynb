# %%
import os
import csv
import pandas as pd

#This script is for loading in various CSV files

#inputDir = '/home/jovyan/GitRepos/high-dimensionality-prediction/DataCSVs/'
inputDir = '/home/jovyan/GitRepos/high-dimensionality-prediction/DataCSVs/'
outputFile = '/home/jovyan/GitRepos/high-dimensionality-prediction/DataCSVs/AllParticipantVoxels.csv'

columnNames = ['SubID','Session', 'Voxels', 'Volume_mm3', 'Percent_of_Total']
particFrame = pd.DataFrame(columns=columnNames)

# %%
for file in os.listdir(inputDir):
    #If the file doesn't start with OAS2, skip the file
    if not file.startswith('OAS2'):
        continue
    if 'MR1' not in file:
        continue
    #Participant ID is based off of the first 9 characters of the filename
    particID = file[:9]
    #Session is based off of the next 4
    particSession = file[10:13]

    curFrame = pd.read_csv(inputDir + file, index_col=0)
    #curFrame = curFrame.rename(columns={curFrame.columns[0]: "Region"})
    curFrame['SubID'] = particID
    curFrame['Session'] = particSession
    dataframes = [particFrame, curFrame]
    particFrame = pd.concat(dataframes)
    

#particFrame = particFrame.rename(columns={particFrame.columns[0]: "Region"})
particFrame.index.name = 'Region'
particFrame.reset_index(inplace=True)

print(particFrame.head())
# Out:
#                   Region      SubID Session    Voxels  Volume_mm3  \
# 0                Unknown  OAS2_0002     MR1  15569248  15569248.0
# 1  Cerebral-White-Matter  OAS2_0002     MR1    471456    471456.0
# 2      Cerebellum-Cortex  OAS2_0002     MR1    112516    112516.0
# 3        superiorfrontal  OAS2_0002     MR1     50895     50895.0
# 4      Lateral-Ventricle  OAS2_0002     MR1     48714     48714.0
#
#    Percent_of_Total
# 0         92.799950
# 1          2.810097
# 2          0.670648
# 3          0.303358
# 4          0.290358
# /tmp/ipykernel_818/3389577301.py:17: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   particFrame = pd.concat(dataframes)

# %%
regionsOfNote= ['CSF',
'entorhinal',
'Amygdala',
'Hippocampus',
'supramarginal',
'Inf-Lat-Vent',
'precentral',
'precuneus',
'fusiform',
'lingual',
'superiortemporal',
'lateraloccipital',
'inferiortemporal',
'middletemporal',
'inferiorparietal',
'superiorfrontal',
'Cerebellum-Cortex',
'WM-hypointensities',
'Lateral-Ventricle',
'Cerebral-White-Matter']

delta_regions = ["delta_" + reg for reg in regionsOfNote]
delta_regions
# Out:
# ['delta_CSF',
#  'delta_entorhinal',
#  'delta_Amygdala',
#  'delta_Hippocampus',
#  'delta_supramarginal',
#  'delta_Inf-Lat-Vent',
#  'delta_precentral',
#  'delta_precuneus',
#  'delta_fusiform',
#  'delta_lingual',
#  'delta_superiortemporal',
#  'delta_lateraloccipital',
#  'delta_inferiortemporal',
#  'delta_middletemporal',
#  'delta_inferiorparietal',
#  'delta_superiorfrontal',
#  'delta_Cerebellum-Cortex',
#  'delta_WM-hypointensities',
#  'delta_Lateral-Ventricle',
#  'delta_Cerebral-White-Matter']

# %%
particFrame =particFrame[particFrame.Region.isin(regionsOfNote)]

particFrame
# Out:
#                      Region      SubID Session  Voxels  Volume_mm3  \
# 1     Cerebral-White-Matter  OAS2_0002     MR3  444013    444013.0
# 2         Cerebellum-Cortex  OAS2_0002     MR3  107769    107769.0
# 3         Lateral-Ventricle  OAS2_0002     MR3   63588     63588.0
# 4           superiorfrontal  OAS2_0002     MR3   48970     48970.0
# 5          lateraloccipital  OAS2_0002     MR3   29406     29406.0
# ...                     ...        ...     ...     ...         ...
# 1663                lingual  OAS2_0095     MR3    7123      7123.0
# 1667           Inf-Lat-Vent  OAS2_0095     MR3    5266      5266.0
# 1674               Amygdala  OAS2_0095     MR3    3043      3043.0
# 1675             entorhinal  OAS2_0095     MR3    2647      2647.0
# 1680                    CSF  OAS2_0095     MR3    1249      1249.0
#
#       Percent_of_Total
# 1             2.646524
# 2             0.642353
# 3             0.379014
# 4             0.291884
# 5             0.175273
# ...                ...
# 1663          0.042456
# 1667          0.031388
# 1674          0.018138
# 1675          0.015777
# 1680          0.007445
#
# [660 rows x 6 columns]

# %%
test = particFrame.pivot_table(index="SubID", columns="Region", values="Percent_of_Total")
print(test.head())
# Out:
# Region     Amygdala       CSF  Cerebellum-Cortex  Cerebral-White-Matter  \
# SubID
# OAS2_0002  0.010902  0.013840           0.642353               2.646524
# OAS2_0005  0.019282  0.011468           0.672805               2.220690
# OAS2_0007  0.012207  0.009125           0.681210               2.011210
# OAS2_0012  0.012928  0.007039           0.501573               2.129692
# OAS2_0013  0.015491  0.009006           0.475484               1.781738
#
# Region     Hippocampus  Inf-Lat-Vent  Lateral-Ventricle  WM-hypointensities  \
# SubID
# OAS2_0002     0.033832      0.021690           0.379014            0.037730
# OAS2_0005     0.048292      0.028348           0.396144            0.200582
# OAS2_0007     0.036824      0.011957           0.212890            0.042039
# OAS2_0012     0.038224      0.014371           0.172108            0.087780
# OAS2_0013     0.035268      0.010067           0.221837            0.028962
#
# Region     entorhinal  fusiform  inferiorparietal  inferiortemporal  \
# SubID
# OAS2_0002    0.009429  0.071865          0.123125          0.103456
# OAS2_0005    0.019330  0.074738          0.140542          0.122279
# OAS2_0007    0.009757  0.063145          0.103259          0.120085
# OAS2_0012    0.013709  0.062913          0.108320          0.107205
# OAS2_0013    0.013548  0.065261          0.124979          0.113213
#
# Region     lateraloccipital   lingual  middletemporal  precentral  precuneus  \
# SubID
# OAS2_0002          0.175273  0.082701        0.103033    0.146717   0.116032
# OAS2_0005          0.128084  0.069320        0.140131    0.126690   0.112104
# OAS2_0007          0.107545  0.061595        0.124574    0.135130   0.079846
# OAS2_0012          0.100905  0.051725        0.114578    0.114316   0.081253
# OAS2_0013          0.125551  0.063056        0.113404    0.125623   0.086010
#
# Region     superiorfrontal  superiortemporal  supramarginal
# SubID
# OAS2_0002         0.291884          0.168931       0.118268
# OAS2_0005         0.269872          0.156313       0.102085
# OAS2_0007         0.273728          0.168341       0.101227
# OAS2_0012         0.210822          0.150299       0.086963
# OAS2_0013         0.225782          0.158155       0.085735

# %%
test.to_csv(outputFile,mode='w')
